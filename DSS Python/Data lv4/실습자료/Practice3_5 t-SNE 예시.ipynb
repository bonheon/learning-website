# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from mpl_toolkits.mplot3d import axes3d

# %%
X = pd.read_csv("data/X_t_sne.csv")
y = pd.read_csv("data/y_t_sne.csv")

# %%
temp = X.values

# %%
y = y.values.reshape(-1)

# %%
cluster0 = temp[y==0]
cluster1 = temp[y==1]

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(cluster0[:, 0], cluster0[:, 1], cluster0[:, 2], marker='o', c='blue', s=20)
ax.scatter(cluster1[:, 0], cluster1[:, 1], cluster1[:, 2], marker='o', c='orange', s=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(perplexity=2)

# %%
embeddings = tsne.fit_transform(temp)
# Out:
# C:\Users\jkchoi\miniconda3\envs\ADD\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\jkchoi\miniconda3\envs\ADD\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
cluster0 = embeddings[y==0]
cluster1 = embeddings[y==1]

# %%
fig = plt.figure(figsize=(5, 5))
plt.scatter(cluster0[:, 0], cluster0[:, 1], marker='o', c='blue', s=20)
plt.scatter(cluster1[:, 0], cluster1[:, 1], marker='o', c='orange', s=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
tsne = TSNE(perplexity=20)

# %%
embeddings = tsne.fit_transform(temp)
# Out:
# C:\Users\jkchoi\miniconda3\envs\ADD\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\jkchoi\miniconda3\envs\ADD\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
cluster0 = embeddings[y==0]
cluster1 = embeddings[y==1]

# %%
fig = plt.figure(figsize=(5, 5))
plt.scatter(cluster0[:, 0], cluster0[:, 1], marker='o', c='blue', s=20)
plt.scatter(cluster1[:, 0], cluster1[:, 1], marker='o', c='orange', s=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
tsne = TSNE(perplexity=100)

# %%
embeddings = tsne.fit_transform(temp)
# Out:
# C:\Users\jkchoi\miniconda3\envs\ADD\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\jkchoi\miniconda3\envs\ADD\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
cluster0 = embeddings[y==0]
cluster1 = embeddings[y==1]

# %%
fig = plt.figure(figsize=(5, 5))
plt.scatter(cluster0[:, 0], cluster0[:, 1], marker='o', c='blue', s=20)
plt.scatter(cluster1[:, 0], cluster1[:, 1], marker='o', c='orange', s=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
tsne = TSNE(perplexity=1500)

# %%
embeddings = tsne.fit_transform(temp)
# Out:
# C:\Users\jkchoi\miniconda3\envs\ADD\lib\site-packages\sklearn\manifold\_t_sne.py:800: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\jkchoi\miniconda3\envs\ADD\lib\site-packages\sklearn\manifold\_t_sne.py:810: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
cluster0 = embeddings[y==0]
cluster1 = embeddings[y==1]

# %%
fig = plt.figure(figsize=(5, 5))
plt.scatter(cluster0[:, 0], cluster0[:, 1], marker='o', c='blue', s=20)
plt.scatter(cluster1[:, 0], cluster1[:, 1], marker='o', c='orange', s=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
